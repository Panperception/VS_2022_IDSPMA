# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path4= "/content/drive/MyDrive/thesisData/data2.csv"
data = pd.read_csv(path4)

# %%
data

# %%
data = data.drop('Unnamed: 0', 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
allfeats = data.columns
allfeats = list(allfeats)

# %%
data.iloc[:,2] = data.iloc[:,2].astype(np.float64)
data[allfeats]
# Out:
#         CellLine                 Drug_ID      IC50  TSPAN6 (7105)  \
# 0     ACH-000001  BRD-A00077618-236-07-6 -0.015577       0.660690
# 1     ACH-000007  BRD-A00077618-236-07-6 -0.095730       0.457352
# 2     ACH-000008  BRD-A00077618-236-07-6  0.379480       0.393372
# 3     ACH-000010  BRD-A00077618-236-07-6  0.118890       0.504589
# 4     ACH-000011  BRD-A00077618-236-07-6  0.145346       0.517355
# ...          ...                     ...       ...            ...
# 2995  ACH-000348  BRD-A00520476-001-07-4  0.166729       0.407404
# 2996  ACH-000350  BRD-A00520476-001-07-4  0.085777       0.582676
# 2997  ACH-000351  BRD-A00520476-001-07-4  0.156226       0.523484
# 2998  ACH-000352  BRD-A00520476-001-07-4  0.528791       0.454117
# 2999  ACH-000356  BRD-A00520476-001-07-4  0.257668       0.555988
#
#       TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  C1orf112 (55732)  FGR (2268)  \
# 0              0.0     0.686665       0.361583          0.703378    0.005316
# ...

# %%
df = data.drop('CellLine', 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
df = df.drop('Drug_ID', 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
df = df.drop('IC50', 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#       TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  \
# 0          0.660690           0.0     0.686665       0.361583
# 1          0.457352           0.0     0.410468       0.594680
# 2          0.393372           0.0     0.636089       0.386495
# 3          0.504589           0.0     0.660830       0.434795
# 4          0.517355           0.0     0.350141       0.365596
# ...             ...           ...          ...            ...
# 2995       0.407404           0.0     0.645604       0.396125
# 2996       0.582676           0.0     0.547007       1.000000
# 2997       0.523484           0.0     0.814655       0.422830
# 2998       0.454117           0.0     0.413047       0.726611
# 2999       0.555988           0.0     0.601069       0.567271
#
#       C1orf112 (55732)  FGR (2268)  CFH (3075)  FUCA2 (2519)  GCLC (2729)  \
# 0             0.703378    0.005316    0.093893      0.659213     0.416510
# ...

# %%
y = data.iloc[:,2]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2, random_state=0)

# %%
from sklearn.feature_selection import mutual_info_regression
# determine the mutual information
mutual_info = mutual_info_regression(X_train, y_train)
mutual_info
# Out:
# array([0.00826843, 0.        , 0.00454715, ..., 0.01246306, 0.01059515,
#        0.        ])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# PLAC8 (51316)              0.068000
# ALAD (210)                 0.062950
# WDR86 (349136)             0.062662
# KDM3B (51780)              0.060377
# EXTL1 (2134)               0.060224
#                              ...
# UBC (7316)                 0.000000
# PRSS53 (339105)            0.000000
# THRB (7068)                0.000000
# OXSM (54995)               0.000000
# GET1-SH3BGR (106865373)    0.000000
# Length: 19167, dtype: float64

# %%
a=mutual_info.sort_values(ascending=False)

# %%
from sklearn.feature_selection import SelectPercentile

# %%
## Selecting the top 50 percentile
selected_top_columns = SelectPercentile(mutual_info_regression, percentile=50)
selected_top_columns.fit(X_train, y_train)
# Out:
# SelectPercentile(percentile=50,
#                  score_func=<function mutual_info_regression at 0x7fcba2f45050>)

# %%
b=X_train.columns[selected_top_columns.get_support()]

# %%
df2 = pd.DataFrame(b)

# %%
Fdata = data.loc[:,data.columns.isin(b)]

# %%
Fdata
# Out:
#       TSPAN6 (7105)  FGR (2268)  CFH (3075)  FUCA2 (2519)  GCLC (2729)  \
# 0          0.660690    0.005316    0.093893      0.659213     0.416510
# 1          0.457352    0.003561    0.001480      0.644058     0.450714
# 2          0.393372    0.000000    0.010063      0.746335     0.423843
# 3          0.504589    0.003561    0.351003      0.780624     0.370504
# 4          0.517355    0.000000    0.039023      0.643084     0.374826
# ...             ...         ...         ...           ...          ...
# 2995       0.407404    0.026690    0.253827      0.754683     0.297743
# 2996       0.582676    0.007053    0.076275      0.577088     0.358069
# 2997       0.523484    0.204617    0.035550      0.697735     0.410381
# 2998       0.454117    0.001789    0.050045      0.536170     0.488895
# 2999       0.555988    0.005316    0.004396      0.758887     0.589969
#
#       NFYA (4800)  STPG1 (90529)  LAS1L (81887)  CFTR (1080)  CYP51A1 (1595)  \
# ...

# %%
y = data.iloc[:,2]

# %%
y
# Out:
# 0      -0.015577
# 1      -0.095730
# 2       0.379480
# 3       0.118890
# 4       0.145346
#           ...
# 2995    0.166729
# 2996    0.085777
# 2997    0.156226
# 2998    0.528791
# 2999    0.257668
# Name: IC50, Length: 3000, dtype: float64

# %%
#Fdata.to_csv('/content/drive/MyDrive/thesisData/Fdata(FSxgboost).csv')

# %%
path5= "/content/drive/MyDrive/thesisData/Fdata(FSxgboost).csv"
Reviseddata = pd.read_csv(path5)

# %%
Reviseddata

# %%
Reviseddata = Reviseddata.drop('Unnamed: 0', 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
Reviseddata
# Out:
#       TSPAN6 (7105)  FGR (2268)  CFH (3075)  FUCA2 (2519)  GCLC (2729)  \
# 0          0.660690    0.005316    0.093893      0.659213     0.416510
# 1          0.457352    0.003561    0.001480      0.644058     0.450714
# 2          0.393372    0.000000    0.010063      0.746335     0.423843
# 3          0.504589    0.003561    0.351003      0.780624     0.370504
# 4          0.517355    0.000000    0.039023      0.643084     0.374826
# ...             ...         ...         ...           ...          ...
# 2995       0.407404    0.026690    0.253827      0.754683     0.297743
# 2996       0.582676    0.007053    0.076275      0.577088     0.358069
# 2997       0.523484    0.204617    0.035550      0.697735     0.410381
# 2998       0.454117    0.001789    0.050045      0.536170     0.488895
# 2999       0.555988    0.005316    0.004396      0.758887     0.589969
#
#       NFYA (4800)  STPG1 (90529)  LAS1L (81887)  CFTR (1080)  CYP51A1 (1595)  \
# ...

# %%
y = data.iloc[:,3]

# %%
y
# Out:
# 0      -0.015577
# 1      -0.095730
# 2       0.379480
# 3       0.118890
# 4       0.145346
#           ...
# 2995    0.166729
# 2996    0.085777
# 2997    0.156226
# 2998    0.528791
# 2999    0.257668
# Name: IC50, Length: 3000, dtype: float64

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from xgboost import XGBRegressor

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Reviseddata, y, test_size = 0.2, random_state=40)
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (2400, 9583) (2400,) (600, 9583) (600,)

# %%
X_test.shape
# Out:
# (600, 9583)

# %%
X_train.shape
# Out:
# (2400, 9583)

# %%
y_train.shape
# Out:
# (2400,)

# %%
from numpy import absolute
model = XGBRegressor()
# define model evaluation method
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-e409e23075ef> in <module>()
#       4 cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
#       5 # evaluate model
# ----> 6 scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     518         fit_params=fit_params,
#     519         pre_dispatch=pre_dispatch,
# --> 520         error_score=error_score,
#     521     )
#     522     return cv_results["test_score"]
#
# ...

# %%
# force scores to be positive
scores = absolute(scores)
print('Mean MAE: %.3f (%.3f)' % (scores.mean(), scores.std()) )

# %%
model = XGBRegressor()
model.fit(X_train, y_train)
# Out:
# [16:13:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()

# %%
preds = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 0.469757

# %%
from xgboost import plot_importance
from matplotlib import pyplot as plt
model.fit(Fdata, y)
# feature importance
print(model.feature_importances_)
# plot
fig, ax = plt.subplots(figsize=(100,100))
plt.bar(range(len(model.feature_importances_)), model.feature_importances_)
plt.show()
# Out:
# [07:08:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-d20d21cd35fc> in <module>()
#       1 from xgboost import plot_importance
#       2 from matplotlib import pyplot as plt
# ----> 3 model.fit(Fdata, y)
#       4 # feature importance
#       5 print(model.feature_importances_)
#
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     394                               evals_result=evals_result, obj=obj, feval=feval,
#     395                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 396                               callbacks=callbacks)
#     397
# ...

# %%
fig, ax = pyplot.subplots(figsize=(100,100))
pyplot.bar(range(len(model.feature_importances_)), model.feature_importances_)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-531e84f3ee7f> in <module>()
# ----> 1 fig, ax = pyplot.subplots(figsize=(100,100))
#       2 pyplot.bar(range(len(model.feature_importances_)), model.feature_importances_)
#       3 pyplot.show()
#
# NameError: name 'pyplot' is not defined

# %%
from matplotlib import pyplot 
from xgboost import plot_importance
pyplot.figure(figsize=(2000, 5000))
plot_importance(model)
pyplot.show()
ax = xgboost.plot_importance(...)
fig = ax.figure
fig.set_size_inches(h, w)

# %%
# select features using threshold
feature_counts = [] 
feature_lists=[]
from sklearn.feature_selection import SelectFromModel
for i in range(50): 
  sfm = SelectFromModel(estimator = model, threshold=None, prefit=False, norm_order=1, max_features = 300)
  sfm.fit(Fdata, y)
  modfeats = sfm.get_support()
  Xred = Fdata.iloc[:,modfeats]
  modfeats = list(Xred.columns)
  feature_lists.append(modfeats)

# %%
feature_lists = np.unique(feature_lists)
len(feature_lists)
# Out:
# 300

# %%
len(feature_lists)
# Out:
# 300

# %%
fig, ax = plt.subplots(figsize=(100,100))
plot_importance(model, max_num_features=200, height=0.5, ax=ax,importance_type='gain')
plt.show()

# %%
pip install shap
# Out:
# ...
#      |████████████████████████████████| 564 kB 31.4 MB/s
# ...

# %%
col= Fdata.columns

# %%
import random
X_sampled = random.sample(X_train, 4))

# %%
X_sampled=X_test

# %%
import shap
explainer = shap.TreeExplainer(model,X_sampled)

# %%
shap_values = explainer(X_sampled)

# %%
shap_values = explainer.shap_values(X_sampled)

# %%
# load JS visualization code to notebook
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
shap_values = shap.TreeExplainer(model).shap_values(X_train)

# %% [markdown]
# **Global bar plot**

# %%
explainer = shap.Explainer(model, X_train)
shap_values = explainer.shap_values(X_sampled)

# %% [markdown]
# **beeswarm summary plot**

# %%
shap.plots.bar(shap_values)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-88-226c8b35369d> in <module>()
# ----> 1 shap.plots.bar(shap_values)
#
# /usr/local/lib/python3.7/dist-packages/shap/plots/_bar.py in bar(shap_values, max_display, order, clustering, clustering_cutoff, merge_cohorts, show_data, show)
#      49         cohorts = shap_values.cohorts
#      50     else:
# ---> 51         assert isinstance(shap_values, dict), "You must pass an Explanation object, Cohorts object, or dictionary to bar plot!"
#      52
#      53     # unpack our list of Explanation objects we need to plot
#
# AssertionError: You must pass an Explanation object, Cohorts object, or dictionary to bar plot!

# %% [markdown]
# **Waterfall**

# %%
import shap

# %%
# compute SHAP values
explainer = shap.Explainer(model, X_train)
shap_values = explainer(X_train)
# Out:
#  98%|===================| 2350/2400 [00:13<00:00]

# %%
shap.plots.bar(shap_values)

# %% [markdown]
# **Local bar plot**

# %%
shap.plots.bar(shap_values[0])

# %%
clustering = shap.utils.hclust(X_train, y_train) # by default this trains (X.shape[1] choose 2) 2-feature XGBoost models
shap.plots.bar(shap_values, clustering=clustering)

# %%
# summarize the effects of all the features
shap.summary_plot(shap_values, X_sampled)

# %%
shap.summary_plot(shap_values, X_sampled, plot_type="bar")

# %%
pip install shap

# %%
import shap

# %%
import numpy as np
a=np.random.randint(15,size=(4,3))

# %%
a
# Out:
# array([[10,  3,  0],
#        [10, 10,  1],
#        [ 1,  4, 12],
#        [ 8,  9,  8]])

# %%
a[:3]
# Out:
# array([[10,  3,  0],
#        [10, 10,  1],
#        [ 1,  4, 12]])

# %%
X_test.shape
X_train.shape
# Out:
# (2400, 9583)

# %%
explainer = shap.TreeExplainer(model=model,
                               data=None,
                               model_output='raw',
                               feature_perturbation='tree_path_dependent')

# %%
global shap_values 
shap_values= explainer.shap_values(X_train)

# %%
shap.initjs()
#shap.force_plot(explainer.expected_value, shap_values, features=X_train)
shap.force_plot(explainer.expected_value, shap_values[:100], X_train.iloc[:100])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
shap.initjs()
#shap.force_plot(explainer.expected_value, shap_values, features=X_train)
shap.force_plot(explainer.expected_value, shap_values[0,:], X_train.iloc[0,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# **decision plot**

# %%
shap.decision_plot(explainer.expected_value, shap_values[:50], X_train[:50])

# %%
import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    shap_values = explainer.shap_values(X_train.columns)[1]
    shap_interaction_values = explainer.shap_interaction_values(X_train.columns)
if isinstance(shap_interaction_values, list):
    shap_interaction_values = shap_interaction_values[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/base.py in asformat(self, format, copy)
#     325             try:
# --> 326                 return convert_method(copy=copy)
#     327             except TypeError:
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/coo.py in tocsr(self, copy)
#     405             indices = np.empty_like(col, dtype=idx_dtype)
# --> 406             data = np.empty_like(self.data, dtype=upcast(self.dtype))
#     407
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/sputils.py in upcast(*args)
#      52
# ---> 53     raise TypeError('no supported conversion for types: %r' % (args,))
#      54
#
# TypeError: no supported conversion for types: (dtype('O'),)
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
shap.decision_plot(explainer.expected_value, shap_interaction_values, X[misclassified],
                   link='logit')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-a6ee279f470b> in <module>()
# ----> 1 shap.decision_plot(explainer.expected_value, shap_interaction_values[misclassified], X[misclassified],
#       2                    link='logit')
#
# NameError: name 'shap_interaction_values' is not defined

# %%
select = range(50)

# %%
X = X_train[0:100]

# %%
y = y_train[0:100]

# %%
global shap_values 
shap_values= explainer.shap_values(X)

# %%
# Our naive cutoff point is zero log odds (probability 0.5).
y_pred = (shap_values.sum(1) + explainer.expected_value) > 0
misclassified = y_pred != y
shap.decision_plot(explainer.expected_value, shap_values, X, link='logit', highlight=misclassified)

# %%
shap.decision_plot(explainer.expected_value, shap_values[misclassified], X[misclassified],
                   link='logit', highlight=0)

# %%
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[:50], X_train[:50])

# %%
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, X, display_features=X_display)

# %%
shap.summary_plot(shap_values, X_train)

# %%
shap.summary_plot(shap_values, features=col)

# %%
shap.summary_plot(shap_values, max_display=50)

# %%
shap.summary_plot(shap_values, X_train)

# %%
shap.summary_plot(shap_values, X_train, plot_type="bar")

# %%
shap.plots.heatmap(shap_values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-5c36a6a86c36> in <module>()
# ----> 1 shap.plots.heatmap(shap_values)
#
# /usr/local/lib/python3.7/dist-packages/shap/plots/_heatmap.py in heatmap(shap_values, instance_order, feature_values, feature_order, max_display, cmap, show)
#      46
#      47     # sort the SHAP values matrix by rows and columns
# ---> 48     values = shap_values.values
#      49     if issubclass(type(feature_values), OpChain):
#      50         feature_values = feature_values.apply(Explanation(values))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
#shap.plots.waterfall(shap_values.values)
shap.plots._waterfall.waterfall_legacy(explainer.expected_value, shap_values[0,:], X_train.iloc[0,:])

# %%
shap.plots.beeswarm( shap_values[0,:], X_train.iloc[0,:])
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-70-4bb6c63863f7> in <module>()
# ----> 1 shap.plots.beeswarm( shap_values[0,:], X_train.iloc[0,:])
#
# /usr/local/lib/python3.7/dist-packages/shap/plots/_beeswarm.py in beeswarm(shap_values, max_display, order, clustering, cluster_threshold, color, axis_color, alpha, show, log_scale, color_bar, plot_size, color_bar_label)
#      65         #     out_names = shap_exp.output_names
#      66
# ---> 67     order = convert_ordering(order, values)
#      68
#      69
#
# UnboundLocalError: local variable 'values' referenced before assignment

# %%
# The first argument is the index of the feature we want to plot
# The second argument is the matrix of SHAP values (it is the same shape as the data matrix)
# The third argument is the data matrix (a pandas dataframe or numpy array)
shap.dependence_plot("rank(1)", shap_values, X_train)

# %%
shap.dependence_plot("NCKAP5 (344148)", shap_values, X_train)

# %%
shap.plots.heatmap(shap_values)

# %%
shap_values = shap.TreeExplainer(model).shap_values(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-2d7472f0be05> in <module>()
# ----> 1 shap_values = shap.TreeExplainer(model).shap_values(X_train)
#
# NameError: name 'shap' is not defined

# %%
shap.summary_plot(shap_values, X_train)

# %%
# takes a couple minutes since SHAP interaction values take a factor of 2 * # features
# more time than SHAP values to compute, since this is just an example we only explain
# the first 2,000 people in order to run quicker
shap_interaction_values = shap.TreeExplainer(model).shap_interaction_values(X_train.iloc[:2000,:])

# %%
# we pass "Age" instead of an index because dependence_plot() will find it in X's column names for us
# Systolic BP was automatically chosen for coloring based on a potential interaction to check that 
# the interaction is really in the model see SHAP interaction values below
shap.dependence_plot("DIPK2A (205428)", shap_values, X_train)
# Out:
# invalid value encountered in true_divide
# invalid value encountered in true_divide

# %%
shap.dependence_plot("VPS54 (51542)", shap_values, X_train)

# %%
shap.dependence_plot("CPNE8 (144402)", shap_values, X_train)

# %%
shap.dependence_plot("DERL1 (79139)", shap_values, X_train)
# Out:
# invalid value encountered in true_divide
# invalid value encountered in true_divide

# %%
# takes a couple minutes since SHAP interaction values take a factor of 2 * # features
# more time than SHAP values to compute, since this is just an example we only explain
# the first 2,000 people in order to run quicker
shap_interaction_values = shap.TreeExplainer(model).shap_interaction_values(X_train.iloc[:100,:])

# %%
shap.summary_plot(shap_interaction_values, X_train.iloc[:100,:])

# %%
https://slundberg.github.io/shap/notebooks/NHANES%20I%20Survival%20Model.html

# %%
import shap
explainer = shap.TreeExplainer(model)
expected_value = explainer.expected_value
if isinstance(expected_value, list):
    expected_value = expected_value[1]
print(f"Explainer expected value: {expected_value}")

select = range(100)
features = X_test[select]
features_display = Reviseddata.loc[features.index]

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    shap_values = explainer.shap_values(features)[1]
    shap_interaction_values = explainer.shap_interaction_values(features)
if isinstance(shap_interaction_values, list):
    shap_interaction_values = shap_interaction_values[1]
